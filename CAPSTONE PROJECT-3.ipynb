# %% [markdown]
#  # CAPSTONE PROJECT-3

# %% [markdown]
# # TITANIC DATA SET

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\rajus\\Downloads'

# %%
import pandas as pd

# %%
# survival: Survival (0 = No; 1 = Yes)
# pclass: Passenger Class (1 = 1st; 2 = 2nd; 3 = 3rd)
# sex: Sex
# age: Age
# sibsp: Number of Siblings/Spouses Aboard
# parch: Number of Parents/Children Aboard
# fare: Passenger Fare
# embarked: Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)
# deck : Floors on the ship

# %%
titanic=pd.read_csv('titanic.csv')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
# 1 how to see all rows in this data set

# %%
pd.options.display.max_rows=891

# %%
titanic
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked deck
# 0           0       3    male  22.00      1      0    7.2500        S  NaN
# 1           1       1  female  38.00      1      0   71.2833        C    C
# 2           1       3  female  26.00      0      0    7.9250        S  NaN
# 3           1       1  female  35.00      1      0   53.1000        S    C
# 4           0       3    male  35.00      0      0    8.0500        S  NaN
# 5           0       3    male    NaN      0      0    8.4583        Q  NaN
# 6           0       1    male  54.00      0      0   51.8625        S    E
# 7           0       3    male   2.00      3      1   21.0750        S  NaN
# 8           1       3  female  27.00      0      2   11.1333        S  NaN
# 9           1       2  female  14.00      1      0   30.0708        C  NaN
# 10          1       3  female   4.00      1      1   16.7000        S    G
# ...

# %%
# comment: noramally when you import the data set it's showing frist 5 and last 5 rows will be showing
# but using this code you can see complete rows in data set

# %%
# 2 how to see data set info

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
# comment : using this function you can get the total information of this data set.
#like data types and column names etc....

# %%
# 3 how to clasifying gender in this titanic data set

# %%
titanic_male=titanic[titanic['sex']=='male']

# %%
titanic_male
# Out:
#      survived  pclass   sex    age  sibsp  parch      fare embarked deck
# 0           0       3  male  22.00      1      0    7.2500        S  NaN
# 4           0       3  male  35.00      0      0    8.0500        S  NaN
# 5           0       3  male    NaN      0      0    8.4583        Q  NaN
# 6           0       1  male  54.00      0      0   51.8625        S    E
# 7           0       3  male   2.00      3      1   21.0750        S  NaN
# 12          0       3  male  20.00      0      0    8.0500        S  NaN
# 13          0       3  male  39.00      1      5   31.2750        S  NaN
# 16          0       3  male   2.00      4      1   29.1250        Q  NaN
# 17          1       2  male    NaN      0      0   13.0000        S  NaN
# 20          0       2  male  35.00      0      0   26.0000        S  NaN
# 21          1       2  male  34.00      0      0   13.0000        S    D
# 23          1       1  male  28.00      0      0   35.5000        S    A
# ...

# %%
titanic_female=titanic[titanic['sex']=='female']

# %%
titanic_female
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked deck
# 1           1       1  female  38.00      1      0   71.2833        C    C
# 2           1       3  female  26.00      0      0    7.9250        S  NaN
# 3           1       1  female  35.00      1      0   53.1000        S    C
# 8           1       3  female  27.00      0      2   11.1333        S  NaN
# 9           1       2  female  14.00      1      0   30.0708        C  NaN
# 10          1       3  female   4.00      1      1   16.7000        S    G
# 11          1       1  female  58.00      0      0   26.5500        S    C
# 14          0       3  female  14.00      0      0    7.8542        S  NaN
# 15          1       2  female  55.00      0      0   16.0000        S  NaN
# 18          0       3  female  31.00      1      0   18.0000        S  NaN
# 19          1       3  female    NaN      0      0    7.2250        C  NaN
# ...

# %%
# comment: when you need saprete data from male and female you can use this code

# %%
#4 how to find the male and female count

# %%
titanic_male['sex'].count()
# Out:
# 577

# %%
titanic_female['sex'].count()
# Out:
# 314

# %%
# comment : when you need exctly number use this code and find out

# %%
# 5 how many people servived in this data set and should be data will saprete an male and female

# %%
titanic_survived=titanic[titanic["survived"]==1]

# %%
titanic_survived
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked deck
# 1           1       1  female  38.00      1      0   71.2833        C    C
# 2           1       3  female  26.00      0      0    7.9250        S  NaN
# 3           1       1  female  35.00      1      0   53.1000        S    C
# 8           1       3  female  27.00      0      2   11.1333        S  NaN
# 9           1       2  female  14.00      1      0   30.0708        C  NaN
# 10          1       3  female   4.00      1      1   16.7000        S    G
# 11          1       1  female  58.00      0      0   26.5500        S    C
# 15          1       2  female  55.00      0      0   16.0000        S  NaN
# 17          1       2    male    NaN      0      0   13.0000        S  NaN
# 19          1       3  female    NaN      0      0    7.2250        C  NaN
# 21          1       2    male  34.00      0      0   13.0000        S    D
# ...

# %%
titanic_survived['survived'].count()
# Out:
# 342

# %%
male_survived=titanic_male[titanic_male["survived"]==1]

# %%
male_survived
# Out:
#      survived  pclass   sex    age  sibsp  parch      fare embarked deck
# 17          1       2  male    NaN      0      0   13.0000        S  NaN
# 21          1       2  male  34.00      0      0   13.0000        S    D
# 23          1       1  male  28.00      0      0   35.5000        S    A
# 36          1       3  male    NaN      0      0    7.2292        C  NaN
# 55          1       1  male    NaN      0      0   35.5000        S    C
# 65          1       3  male    NaN      1      1   15.2458        C  NaN
# 74          1       3  male  32.00      0      0   56.4958        S  NaN
# 78          1       2  male   0.83      0      2   29.0000        S  NaN
# 81          1       3  male  29.00      0      0    9.5000        S  NaN
# 97          1       1  male  23.00      0      1   63.3583        C    D
# 107         1       3  male    NaN      0      0    7.7750        S  NaN
# 125         1       3  male  12.00      1      0   11.2417        C  NaN
# ...

# %%
male_survived["survived"].count()
# Out:
# 109

# %%
female_survived=titanic_female[titanic_female["survived"]==1]

# %%
female_survived
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked deck
# 1           1       1  female  38.00      1      0   71.2833        C    C
# 2           1       3  female  26.00      0      0    7.9250        S  NaN
# 3           1       1  female  35.00      1      0   53.1000        S    C
# 8           1       3  female  27.00      0      2   11.1333        S  NaN
# 9           1       2  female  14.00      1      0   30.0708        C  NaN
# 10          1       3  female   4.00      1      1   16.7000        S    G
# 11          1       1  female  58.00      0      0   26.5500        S    C
# 15          1       2  female  55.00      0      0   16.0000        S  NaN
# 19          1       3  female    NaN      0      0    7.2250        C  NaN
# 22          1       3  female  15.00      0      0    8.0292        Q  NaN
# 25          1       3  female  38.00      1      5   31.3875        S  NaN
# ...

# %%
female_survived["survived"].count()
# Out:
# 233

# %%
# comment: using this codes find the total survived peoples  data and saprete male and female people data

# %%
# 6 if i want to filter the data based on a lower limit and upper limit whis function i can use

# %%
titanicbetweenage=titanic[titanic.age.between(20,30)]

# %%
titanicbetweenage
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck
# 0           0       3    male  22.0      1      0    7.2500        S  NaN
# 2           1       3  female  26.0      0      0    7.9250        S  NaN
# 8           1       3  female  27.0      0      2   11.1333        S  NaN
# 12          0       3    male  20.0      0      0    8.0500        S  NaN
# 23          1       1    male  28.0      0      0   35.5000        S    A
# 34          0       1    male  28.0      1      0   82.1708        C  NaN
# 37          0       3    male  21.0      0      0    8.0500        S  NaN
# 41          0       2  female  27.0      1      0   21.0000        S  NaN
# 51          0       3    male  21.0      0      0    7.8000        S  NaN
# 53          1       2  female  29.0      1      0   26.0000        S  NaN
# 56          1       2  female  21.0      0      0   10.5000        S  NaN
# 57          0       3    male  28.5      0      0    7.2292        C  NaN
# ...

# %%
titanicbetweenage['age'].count()
# Out:
# 245

# %%
# comment : when you need spcefic data from your data set use this function

# %%
# 7 how to find out number of unique value

# %%
titanic.nunique()
# Out:
# survived      2
# pclass        3
# sex           2
# age          88
# sibsp         7
# parch         7
# fare        248
# embarked      3
# deck          7
# dtype: int64

# %%
# comment : some time any data set unique number of values is there
#that mean spcefic number of values repeted again and again use this function and find that values

# %%
# 8  find out the null values in our dataset

# %%
titanic.isnull()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked   deck
# 0       False   False  False  False  False  False  False     False   True
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False   True
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False   True
# 5       False   False  False   True  False  False  False     False   True
# 6       False   False  False  False  False  False  False     False  False
# 7       False   False  False  False  False  False  False     False   True
# 8       False   False  False  False  False  False  False     False   True
# 9       False   False  False  False  False  False  False     False   True
# 10      False   False  False  False  False  False  False     False  False
# 11      False   False  False  False  False  False  False     False  False
# ...

# %%
# comment : before using of numrical calculation find the null values 
# after that use the calculation you can get curect information

# %%
# 9 how to use iloc and loc functions

# %%
titanic.iloc[1:20,[0,3,6,8]]
# Out:
#     survived   age     fare deck
# 1          1  38.0  71.2833    C
# 2          1  26.0   7.9250  NaN
# 3          1  35.0  53.1000    C
# 4          0  35.0   8.0500  NaN
# 5          0   NaN   8.4583  NaN
# 6          0  54.0  51.8625    E
# 7          0   2.0  21.0750  NaN
# 8          1  27.0  11.1333  NaN
# 9          1  14.0  30.0708  NaN
# 10         1   4.0  16.7000    G
# 11         1  58.0  26.5500    C
# 12         0  20.0   8.0500  NaN
# 13         0  39.0  31.2750  NaN
# 14         0  14.0   7.8542  NaN
# 15         1  55.0  16.0000  NaN
# 16         0   2.0  29.1250  NaN
# 17         1   NaN  13.0000  NaN
# 18         0  31.0  18.0000  NaN
# 19         1   NaN   7.2250  NaN

# %%
titanic.loc[:,["survived","age","sex"]]
# Out:
#      survived    age     sex
# 0           0  22.00    male
# 1           1  38.00  female
# 2           1  26.00  female
# 3           1  35.00  female
# 4           0  35.00    male
# 5           0    NaN    male
# 6           0  54.00    male
# 7           0   2.00    male
# 8           1  27.00  female
# 9           1  14.00  female
# 10          1   4.00  female
# 11          1  58.00  female
# 12          0  20.00    male
# 13          0  39.00    male
# 14          0  14.00  female
# 15          1  55.00  female
# 16          0   2.00    male
# 17          1    NaN    male
# 18          0  31.00  female
# 19          1    NaN  female
# 20          0  35.00    male
# 21          1  34.00    male
# 22          1  15.00  female
# 23          1  28.00    male
# 24          0   8.00  female
# 25          1  38.00  female
# 26          0    NaN    male
# 27          0  19.00    male
# 28          1    NaN  female
# 29          0    NaN    male
# 30          0  40.00    male
# ...

# %%
# comment : when we need specific rows and colmn use iloc and loc function

# %%
#10 find the co relation

# %%
titanic_corr=titanic.corr()

# %%
titanic_corr
# Out:
#           survived    pclass       age     sibsp     parch      fare
# survived  1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass   -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age      -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp    -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch     0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare      0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
